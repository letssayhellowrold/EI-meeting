# %% [markdown]
# # Tutorial 6: Denoising

# %% [markdown]
# This tutorial demonstrates how to denoise expressions. The data used here is the same as those in Tutorial 1 (Sample 151676 of the DLPFC dataset).

# %% [markdown]
# ## Preparation

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import scanpy as sc
import matplotlib.pyplot as plt
import os
import sys

# %%
import STAGATE_pyG as STAGATE

# %%
section_id = '151676'

# %%
input_dir = os.path.join('Data', section_id)
adata = sc.read_visium(path=input_dir, count_file=section_id+'_filtered_feature_bc_matrix.h5')
adata.var_names_make_unique()
sc.pp.calculate_qc_metrics(adata, inplace=True)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 3460 × 33538
#     obs: 'in_tissue', 'array_row', 'array_col', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
adata = adata[:,adata.var['total_counts']>100]
adata
# Out:
# View of AnnData object with n_obs × n_vars = 3460 × 10747
#     obs: 'in_tissue', 'array_row', 'array_col', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
#Normalization
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

# %%
# read the annotation
Ann_df = pd.read_csv(os.path.join('Data', section_id, section_id+'_truth.txt'), sep='\t', header=None, index_col=0)
Ann_df.columns = ['Ground Truth']

# %%
adata.obs['Ground Truth'] = Ann_df.loc[adata.obs_names, 'Ground Truth']

# %%
plt.rcParams["figure.figsize"] = (3, 3)
sc.pl.spatial(adata, img_key="hires", color=["Ground Truth"])

# %% [markdown]
# ## Constructing the spatial network

# %%
STAGATE.Cal_Spatial_Net(adata, rad_cutoff=150)
STAGATE.Stats_Spatial_Net(adata)
# Out:
# ------Calculating spatial graph...
# The graph contains 20052 edges, 3460 cells.
# 5.7954 neighbors per cell on average.

# %% [markdown]
# ## Denoising expression using STAGATE

# %% [markdown]
# When performing imputation and denoising, set save_reconstrction=True. The reconstructed expressions are saved in 'STAGATE_ReX' of adata.layers.

# %%
adata = STAGATE.train_STAGATE(adata)
# Out:
# Size of Input:  (3460, 10747)
# 100%|██████████| 1000/1000 [00:48<00:00, 20.79it/s]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 3460 × 10747
#     obs: 'in_tissue', 'array_row', 'array_col', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'Ground Truth'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts'
#     uns: 'spatial', 'log1p', 'Ground Truth_colors', 'Spatial_Net'
#     obsm: 'spatial', 'STAGATE'

# %%
plot_gene = 'ATP2B4'
fig, axs = plt.subplots(1, 2, figsize=(8, 4))
sc.pl.spatial(adata, img_key="hires", color=plot_gene, show=False, ax=axs[0], title='RAW_'+plot_gene, vmax='p99')
sc.pl.spatial(adata, img_key="hires", color=plot_gene, show=False, ax=axs[1], title='STAGATE_'+plot_gene, layer='STAGATE_ReX', vmax='p99')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 4
#       2 fig, axs = plt.subplots(1, 2, figsize=(8, 4))
#       3 sc.pl.spatial(adata, img_key="hires", color=plot_gene, show=False, ax=axs[0], title='RAW_'+plot_gene, vmax='p99')
# ----> 4 sc.pl.spatial(adata, img_key="hires", color=plot_gene, show=False, ax=axs[1], title='STAGATE_'+plot_gene, layer='STAGATE_ReX', vmax='p99')
#
# File ~/.local/lib/python3.10/site-packages/typing_extensions.py:2853, in deprecated.__call__.<locals>.wrapper(*args, **kwargs)
#    2850 @functools.wraps(arg)
#    2851 def wrapper(*args, **kwargs):
#    2852     warnings.warn(msg, category=category, stacklevel=stacklevel + 1)
# -> 2853     return arg(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1020, in spatial(adata, basis, img, img_key, library_id, crop_coord, alpha_img, bw, size, scale_factor, spot_size, na_color, show, return_fig, save, **kwargs)
#    1017 cmap_img = "gray" if bw else None
#    1018 circle_radius = size * scale_factor * spot_size * 0.5
# -> 1020 axs = embedding(
#    1021     adata,
#    1022     basis=basis,
#    1023     scale_factor=scale_factor,
#    1024     size=circle_radius,
#    1025     na_color=na_color,
#    1026     show=False,
#    1027     save=False,
#    1028     **kwargs,
#    1029 )
#    1030 if not isinstance(axs, list):
#    1031     axs = [axs]
#
# File ~/.local/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:279, in embedding(adata, basis, color, mask_obs, gene_symbols, use_raw, sort_order, edges, edges_width, edges_color, neighbors_key, arrows, arrows_kwds, groups, components, dimensions, layer, projection, scale_factor, color_map, cmap, palette, na_color, na_in_legend, size, frameon, legend_fontsize, legend_fontweight, legend_loc, legend_fontoutline, colorbar_loc, vmax, vmin, vcenter, norm, add_outline, outline_width, outline_color, ncols, hspace, wspace, title, show, save, ax, return_fig, marker, **kwargs)
#     277 for count, (value_to_plot, dims) in enumerate(zip(color, dimensions)):
#     278     kwargs_scatter = kwargs.copy()  # is potentially mutated for each plot
# --> 279     color_source_vector = _get_color_source_vector(
#     280         adata,
#     281         value_to_plot,
#     282         layer=layer,
#     283         mask_obs=mask_obs,
#     284         use_raw=use_raw,
#     285         gene_symbols=gene_symbols,
#     286         groups=groups,
#     287     )
#     288     color_vector, color_type = _color_vector(
#     289         adata,
#     290         value_to_plot,
#    (...)
#     293         na_color=na_color,
#     294     )
#     296     # Order points
#
# File ~/.local/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1204, in _get_color_source_vector(adata, value_to_plot, mask_obs, use_raw, gene_symbols, layer, groups)
#    1202     values = adata.raw.obs_vector(value_to_plot)
#    1203 else:
# -> 1204     values = adata.obs_vector(value_to_plot, layer=layer)
#    1205 if mask_obs is not None:
#    1206     values[~mask_obs] = np.nan
#
# File ~/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1300, in AnnData.obs_vector(self, k, layer)
#    1294         warnings.warn(
#    1295             "In a future version of AnnData, access to `.X` by passing"
#    1296             " `layer='X'` will be removed. Instead pass `layer=None`.",
#    1297             FutureWarning,
#    1298         )
#    1299         layer = None
# -> 1300 return get_vector(self, k, "obs", "var", layer=layer)
#
# File ~/.local/lib/python3.10/site-packages/anndata/_core/index.py:246, in get_vector(adata, k, coldim, idxdim, layer)
#     244     selected_dim = dims.index(idxdim)
#     245     idx = adata._normalize_indices(make_slice(k, selected_dim))
# --> 246     a = adata._get_X(layer=layer)[idx]
#     247 if issparse(a):
#     248     a = a.toarray()
#
# File ~/.local/lib/python3.10/site-packages/anndata/_core/anndata.py:1262, in AnnData._get_X(self, use_raw, layer)
#    1257     raise ValueError(
#    1258         "Cannot use expression from both layer and raw. You provided:"
#    1259         f"`use_raw={use_raw}` and `layer={layer}`"
#    1260     )
#    1261 if is_layer:
# -> 1262     return self.layers[layer]
#    1263 elif use_raw:
#    1264     if self.raw is None:
#
# File ~/.local/lib/python3.10/site-packages/anndata/_core/aligned_mapping.py:213, in AlignedActual.__getitem__(self, key)
#     212 def __getitem__(self, key: str) -> Value:
# --> 213     return self._data[key]
#
# KeyError: 'STAGATE_ReX'

# %%
plot_gene = 'RASGRF2'
fig, axs = plt.subplots(1, 2, figsize=(8, 4))
sc.pl.spatial(adata, img_key="hires", color=plot_gene, show=False, ax=axs[0], title='RAW_'+plot_gene, vmax='p99')
sc.pl.spatial(adata, img_key="hires", color=plot_gene, show=False, ax=axs[1], title='STAGATE_'+plot_gene, layer='STAGATE_ReX', vmax='p99')
# Out:
# [<AxesSubplot:title={'center':'STAGATE_RASGRF2'}, xlabel='spatial1', ylabel='spatial2'>]

# %%
plot_gene = 'LAMP5'
fig, axs = plt.subplots(1, 2, figsize=(8, 4))
sc.pl.spatial(adata, img_key="hires", color=plot_gene, show=False, ax=axs[0], title='RAW_'+plot_gene, vmax='p99')
sc.pl.spatial(adata, img_key="hires", color=plot_gene, show=False, ax=axs[1], title='STAGATE_'+plot_gene, layer='STAGATE_ReX', vmax='p99')
# Out:
# [<AxesSubplot:title={'center':'STAGATE_LAMP5'}, xlabel='spatial1', ylabel='spatial2'>]

# %%
plot_gene = 'NEFH'
fig, axs = plt.subplots(1, 2, figsize=(8, 4))
sc.pl.spatial(adata, img_key="hires", color=plot_gene, show=False, ax=axs[0], title='RAW_'+plot_gene, vmax='p99')
sc.pl.spatial(adata, img_key="hires", color=plot_gene, show=False, ax=axs[1], title='STAGATE_'+plot_gene, layer='STAGATE_ReX', vmax='p99')
# Out:
# [<AxesSubplot:title={'center':'STAGATE_NEFH'}, xlabel='spatial1', ylabel='spatial2'>]

# %%
plot_gene = 'NTNG2'
fig, axs = plt.subplots(1, 2, figsize=(8, 4))
sc.pl.spatial(adata, img_key="hires", color=plot_gene, show=False, ax=axs[0], title='RAW_'+plot_gene, vmax='p99')
sc.pl.spatial(adata, img_key="hires", color=plot_gene, show=False, ax=axs[1], title='STAGATE_'+plot_gene, layer='STAGATE_ReX', vmax='p99')
# Out:
# [<AxesSubplot:title={'center':'STAGATE_NTNG2'}, xlabel='spatial1', ylabel='spatial2'>]

# %%
plot_gene = 'B3GALT2'
fig, axs = plt.subplots(1, 2, figsize=(8, 4))
sc.pl.spatial(adata, img_key="hires", color=plot_gene, show=False, ax=axs[0], title='RAW_'+plot_gene, vmax='p99')
sc.pl.spatial(adata, img_key="hires", color=plot_gene, show=False, ax=axs[1], title='STAGATE_'+plot_gene, layer='STAGATE_ReX', vmax='p99')
# Out:
# [<AxesSubplot:title={'center':'STAGATE_B3GALT2'}, xlabel='spatial1', ylabel='spatial2'>]
